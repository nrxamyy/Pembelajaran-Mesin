# %%
import pandas as pd

# %%
dataset = '/content/IMO Rank.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#     Year  ALBANIA  ARGENTINA  ARMENIA  AUSTRALIA  AUSTRIA  AZERBAIJAN  \
# 0   2023     80.0         59       32         23       49        54.0
# 1   2022     77.0         42       26         29       56        34.0
# 2   2021     94.0         46       37         18       64        51.0
# 3   2020     77.0         50       37          8       65        65.0
# 4   2019     80.0         53       49         18       60        51.0
# 5   2018     79.0         39       32         11       57        69.0
# 6   2017     76.0         26       41         34       70        42.0
# 7   2016     69.0         57       30         25       46        54.0
# 8   2015     77.0         52       26          6       60        48.0
# 9   2014     77.0         56       39         11       51        61.0
# 10  2013      NaN         67       40         15       48        52.0
# 11  2012      NaN         54       47         27       50        61.0
# ...

# %%
data.head()
# Out:
#    Year  ALBANIA  ARGENTINA  ARMENIA  AUSTRALIA  AUSTRIA  AZERBAIJAN  BELGIUM  \
# 0  2023     80.0         59       32         23       49        54.0       63
# 1  2022     77.0         42       26         29       56        34.0       63
# 2  2021     94.0         46       37         18       64        51.0       43
# 3  2020     77.0         50       37          8       65        65.0       50
# 4  2019     80.0         53       49         18       60        51.0       68
#
#    BANGLADESH  BULGARIA  ...  TUNISIA  TURKEY  TAIWAN  UKRAINE  \
# 0        46.0        25  ...     75.0       8      10       31
# 1        57.0        16  ...     67.0      26      14       17
# 2        43.0        18  ...     56.0      35       9        6
# 3        38.0        38  ...     71.0      26      23       11
# 4        67.0        19  ...     74.0      29      21       11
#
#    UNITED KINGDOM  URUGUAY  USA  UZBEKISTAN  VENEZUELA  VIETNAM
# ...

# %%
print(data.dtypes)
# Out:
# Year            int64
# ALBANIA       float64
# ARGENTINA       int64
# ARMENIA         int64
# AUSTRALIA       int64
#                ...
# URUGUAY       float64
# USA             int64
# UZBEKISTAN    float64
# VENEZUELA     float64
# VIETNAM         int64
# Length: 94, dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#     Year  ALBANIA  ARGENTINA  ARMENIA  AUSTRIA  AZERBAIJAN  BELGIUM  \
# 0   2023     80.0         59       32       49        54.0       63
# 1   2022     77.0         42       26       56        34.0       63
# 2   2021     94.0         46       37       64        51.0       43
# 3   2020     77.0         50       37       65        65.0       50
# 4   2019     80.0         53       49       60        51.0       68
# 5   2018     79.0         39       32       57        69.0       47
# 6   2017     76.0         26       41       70        42.0       62
# 7   2016     69.0         57       30       46        54.0       52
# 8   2015     77.0         52       26       60        48.0       56
# 9   2014     77.0         56       39       51        61.0       59
# 10  2013      NaN         67       40       48        52.0       44
# 11  2012      NaN         54       47       50        61.0       38
# 12  2011     88.0         49       67       36        67.0       43
# ...

# %%
data.describe()
# Out:
#               Year    ALBANIA  ARGENTINA    ARMENIA  AUSTRALIA    AUSTRIA  \
# count    31.000000  26.000000  31.000000  31.000000  31.000000  31.000000
# mean   2008.000000  72.884615  40.709677  40.483871  19.548387  49.193548
# std       9.092121  10.481706  12.019965  13.137405   7.056150  11.205413
# min    1993.000000  50.000000  20.000000  20.000000   6.000000  22.000000
# 25%    2000.500000  67.250000  29.500000  32.000000  14.000000  42.000000
# 50%    2008.000000  73.500000  39.000000  37.000000  21.000000  49.000000
# 75%    2015.500000  78.500000  49.500000  47.500000  25.000000  58.000000
# max    2023.000000  94.000000  67.000000  67.000000  34.000000  70.000000
#
#        AZERBAIJAN    BELGIUM  BANGLADESH   BULGARIA  ...    TUNISIA  \
# count     30.0000  31.000000   19.000000  31.000000  ...  21.000000
# mean      53.6000  48.935484   56.473684  15.096774  ...  74.238095
# std       10.8329  10.353536   17.680399  10.696899  ...   7.924044
# ...

# %%
data.loc[:,"ALBANIA":].corr()
# Out:
#              ALBANIA  ARGENTINA   ARMENIA  AUSTRALIA   AUSTRIA  AZERBAIJAN  \
# ALBANIA     1.000000   0.223860  0.224759  -0.254045  0.321740   -0.068897
# ARGENTINA   0.223860   1.000000 -0.001192  -0.188672  0.054878    0.001319
# ARMENIA     0.224759  -0.001192  1.000000   0.284710  0.207888   -0.066179
# AUSTRALIA  -0.254045  -0.188672  0.284710   1.000000  0.192119   -0.221927
# AUSTRIA     0.321740   0.054878  0.207888   0.192119  1.000000   -0.249093
# ...              ...        ...       ...        ...       ...         ...
# URUGUAY     0.475917   0.379720  0.125478  -0.063632  0.373511   -0.007636
# USA        -0.222322  -0.171170 -0.005103   0.026525 -0.340204    0.046108
# UZBEKISTAN  0.110344   0.325531 -0.384809  -0.156937  0.136226    0.257913
# VENEZUELA   0.371698   0.582932 -0.178576  -0.232958  0.087305   -0.324743
# VIETNAM     0.357315   0.191055  0.331118  -0.112661 -0.027840    0.227493
#
# ...

# %%
# @title ARMENIA vs AUSTRIA

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='ARMENIA', y='AUSTRIA', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Dengan API**

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-3650f5c1-45e5-4f18-9da7-164b82bfde46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3650f5c1-45e5-4f18-9da7-164b82bfde46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "EURO"
# Out:
# ...
# ref                                                      title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# hugomathien/soccer                                       European Soccer Database                          33MB  2016-10-23 22:31:38         211284       4486  0.7058824
# thedevastator/airbnb-prices-in-european-cities           Airbnb Prices in European Cities                   4MB  2023-02-20 09:48:04          13616        201  1.0
# jiashenliu/515k-hotel-reviews-data-in-europe             515K Hotel Reviews Data in Europe                 45MB  2017-08-21 21:19:17          35930        562  0.8235294
# ...

# %%
# !kaggle datasets download lsind18/euro-exchange-daily-rates-19992020
# Out:
# ...
#   0% 0.00/639k [00:00<?, ?B/s]
# 100% 639k/639k [00:00<00:00, 152MB/s]

# %%
# !unzip /content/euro-exchange-daily-rates-19992020.zip
# Out:
# Archive:  /content/euro-exchange-daily-rates-19992020.zip
#   inflating: euro-daily-hist_1999_2022.csv

# %%
pd.read_csv('/content/euro-daily-hist_1999_2022.csv')
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0      2023-12-15               1.6324           1.9558            5.4085
# 1      2023-12-14               1.6288           1.9558            5.3349
# 2      2023-12-13               1.6452           1.9558            5.3609
# 3      2023-12-12               1.6398           1.9558            5.3327
# 4      2023-12-11                1.642           1.9558            5.3169
# ...           ...                  ...              ...               ...
# 6451   1999-01-08               1.8406              NaN               NaN
# 6452   1999-01-07               1.8474              NaN               NaN
# 6453   1999-01-06               1.8820              NaN               NaN
# 6454   1999-01-05               1.8944              NaN               NaN
# 6455   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# ...
